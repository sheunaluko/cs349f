# %% [markdown]
# # SineTrader \\(^o^)/

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from algorithmic_trader_shay import AlgorithmicTrader

# %%
def get_sin_data(bin_interval=None) :  
    cc_data = pd.read_csv("market_data_CC_to_train.csv")
    if bin_interval : 
        
    
t, ps = cc_data['CreationTimestamp'] , cc_data['ExecPrice'].values

# %% [markdown]
# #### The Sin Wave

# %%
plt.plot(t,ps)
